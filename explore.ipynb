# %%
import pandas as pd

# %%
musical_features_df = pd.read_csv('musical_features_dataset.csv')

# %%
musical_features_df.shape
# Out:
# (1000, 55)

# %%
musical_features_df
# Out:
#           filename genre  mfcc1_mean  mfcc1_std  mfcc2_mean  mfcc2_std  \
# 0     pop.00080.au   pop  -44.972015  59.464615   69.765335  28.840467
# 1     pop.00022.au   pop  -45.717810  65.843540   65.287415  24.014336
# 2     pop.00073.au   pop   -8.531341  55.027363   54.251755  23.107737
# 3     pop.00047.au   pop  -45.064255  59.482147   69.785760  28.824137
# 4     pop.00016.au   pop  -97.008200  80.706660   51.786003  24.823740
# ..             ...   ...         ...        ...         ...        ...
# 995  jazz.00027.au  jazz -262.124400  44.280792  108.982350  15.101414
# 996  jazz.00076.au  jazz -154.292880  57.902040  110.684950  22.559677
# 997  jazz.00085.au  jazz -131.931350  45.454372   61.590870  22.685814
# 998  jazz.00042.au  jazz -206.784930  68.336070  141.837390  23.071640
# 999  jazz.00013.au  jazz -217.644520  29.847910  112.637870  11.771240
#
#      mfcc3_mean  mfcc3_std  mfcc4_mean  mfcc4_std  ...  spectral_rolloff_std  \
# ...
